 [0, 7, 10, 15, 1, 3, 12, 9, 4, 6, 13, 5, 11, 17, 2, 16, 14, 8],
 [0, 7, 10, 12, 1, 15, 13, 3, 4, 5, 9, 6, 2, 11, 17, 16, 14, 8],
 [0, 7, 3, 10, 12, 1, 15, 9, 4, 13, 5, 6, 11, 2, 17, 16, 14, 8],
 [0, 3, 7, 9, 10, 15, 6, 12, 13, 1, 4, 5, 17, 11, 2, 16, 14, 8],
 [0, 7, 10, 1, 12, 3, 15, 9, 6, 13, 4, 5, 11, 2, 17, 16, 14, 8],
 [0, 7, 10, 1, 3, 12, 15, 9, 4, 6, 13, 5, 11, 2, 17, 16, 14, 8],
 [0, 7, 10, 9, 1, 12, 3, 15, 13, 4, 5, 6, 17, 11, 16, 14, 2, 8],
 [0, 7, 10, 3, 15, 4, 5, 13, 9, 12, 6, 1, 11, 2, 17, 16, 14, 8],
 [0, 7, 10, 15, 6, 3, 9, 11, 12, 13, 1, 4, 5, 17, 2, 16, 14, 8],
 [0, 7, 10, 3, 9, 15, 4, 12, 13, 5, 6, 1, 11, 17, 2, 16, 14, 8],
 [0, 10, 7, 1, 12, 15, 3, 9, 4, 6, 13, 5, 17, 11, 2, 16, 14, 8],
 [0, 7, 10, 3, 15, 6, 1, 12, 9, 13, 11, 5, 17, 2, 4, 16, 14, 8],
 [0, 7, 10, 3, 9, 15, 12, 13, 1, 4, 6, 5, 17, 11, 2, 16, 14, 8],
 [0, 7, 10, 15, 3, 1, 12, 6, 9, 13, 4, 2, 17, 5, 11, 16, 14, 8],
 [0, 7, 10, 3, 12, 15, 9, 13, 5, 1, 4, 6, 11, 17, 2, 16, 14, 8],
 [0, 7, 10, 15, 12, 1, 3, 9, 13, 6, 5, 17, 4, 2, 11, 16, 14, 8],
 [0, 3, 10, 7, 9, 15, 12, 17, 6, 13, 1, 5, 16, 11, 4, 2, 14, 8],
 [0, 7, 10, 1, 15, 3, 9, 12, 6, 13, 4, 5, 17, 11, 2, 16, 14, 8],
 [0, 7, 10, 3, 9, 15, 12, 1, 13, 6, 4, 5, 17, 11, 2, 16, 14, 8],
 [0, 7, 10, 3, 4, 12, 13, 15, 1, 9, 5, 6, 17, 11, 2, 16, 14, 8],
 [0, 7, 10, 9, 1, 12, 15, 3, 13, 4, 5, 6, 2, 17, 11, 16, 14, 8]]

# %%
import Aggregation.sampling as sp

schedule = []
for _ in range(10):
    schedule.append((0.6, 1.5))
for _ in range(10):
    schedule.append((0.4, 1.0))
for _ in range(10):
    schedule.append((0.2, 0.6))
for _ in range(10):
    schedule.append((0.15, 0.4))
for _ in range(10):
    schedule.append((0.1, 0.2))

log = sp.theta_estimation(profile_llama3, alternative_number=18, iteration=50, sampling_rate=1000, keep_rate=100, resampling_schedule=schedule)
# Out:
# game list loaded
# iteration 0: average likelihood (log_value) is   -0.8384592975309838
# iteration 1: average likelihood (log_value) is   -0.5894274647966409
# iteration 2: average likelihood (log_value) is   -0.5822586517070649
# iteration 3: average likelihood (log_value) is   -0.5753902221670139
# iteration 4: average likelihood (log_value) is   -0.5713139401698414
# iteration 5: average likelihood (log_value) is   -0.5689280880348339
# iteration 6: average likelihood (log_value) is   -0.5648178661384403
# iteration 7: average likelihood (log_value) is   -0.562976169857674
# iteration 8: average likelihood (log_value) is   -0.5588283118499825
# iteration 9: average likelihood (log_value) is   -0.5556086906074117
# iteration 10: average likelihood (log_value) is   -0.5555154610332643
# iteration 11: average likelihood (log_value) is   -0.39009698049456426
# iteration 12: average likelihood (log_value) is   -0.3826188849546574
# iteration 13: average likelihood (log_value) is   -0.37540271932321806
# iteration 14: average likelihood (log_value) is   -0.37335159009871244
# iteration 15: average likelihood (log_value) is   -0.36885781456864025
# iteration 16: average likelihood (log_value) is   -0.3636180957328453
# iteration 17: average likelihood (log_value) is   -0.36239498605383513
# iteration 18: average likelihood (log_value) is   -0.35811815166543975
# iteration 19: average likelihood (log_value) is   -0.35596335091423364
# iteration 20: average likelihood (log_value) is   -0.3537535527828424
# iteration 21: average likelihood (log_value) is   -0.17422553897715096
# iteration 22: average likelihood (log_value) is   -0.16384996936638724
# iteration 23: average likelihood (log_value) is   -0.15176920384858827
# iteration 24: average likelihood (log_value) is   -0.14531030809180684
# iteration 25: average likelihood (log_value) is   -0.13709279906593347
# iteration 26: average likelihood (log_value) is   -0.1338492516304592
# iteration 27: average likelihood (log_value) is   -0.12797306402112107
# iteration 28: average likelihood (log_value) is   -0.12513783032119596
# iteration 29: average likelihood (log_value) is   -0.12092806022327399
# iteration 30: average likelihood (log_value) is   -0.11663647293207294
# iteration 31: average likelihood (log_value) is   -0.05603365761457923
# iteration 32: average likelihood (log_value) is   -0.05093850983227586
# iteration 33: average likelihood (log_value) is   -0.045319525724367406
# iteration 34: average likelihood (log_value) is   -0.040273019783689974
# iteration 35: average likelihood (log_value) is   -0.037154073923606555
# iteration 36: average likelihood (log_value) is   -0.03318372729607603
# iteration 37: average likelihood (log_value) is   -0.03137135255317347
# iteration 38: average likelihood (log_value) is   -0.02659720948850763
# iteration 39: average likelihood (log_value) is   -0.023879619973423222
# iteration 40: average likelihood (log_value) is   -0.019979740249974603
# iteration 41: average likelihood (log_value) is   0.03331727244632835
# iteration 42: average likelihood (log_value) is   0.03804870520032907
# iteration 43: average likelihood (log_value) is   0.042013700386333036
# iteration 44: average likelihood (log_value) is   0.044972014197678975
# iteration 45: average likelihood (log_value) is   0.04764657086919536
# iteration 46: average likelihood (log_value) is   0.04858954926268564
# iteration 47: average likelihood (log_value) is   0.05047801108171046
# iteration 48: average likelihood (log_value) is   0.052127492287993266
# iteration 49: average likelihood (log_value) is   0.052573415216811796

# %%
log[49]
# Out:
# {'iteration': 49,
#  'average_log_likelihood': 0.052573415216811796,
#  'zeta_estimation': array([[-7.24106880e-02,  4.41216496e-03, -8.07264404e-03,
#          -3.91347202e-02, -9.42652965e-03, -1.16397753e-02,
#           2.07797011e-02, -1.35400465e-03,  6.93756073e-02,
#           2.48009108e-02, -1.44103616e-02,  7.49893114e-03,
#          -2.48578985e-03,  2.22439602e-03,  5.18567581e-02],
#         [-7.13144876e-02, -6.67044633e-03, -4.05874360e-03,
#          -4.80381674e-02, -1.14429088e-02, -8.10398631e-03,
#           1.01379531e-02,  8.58855859e-03,  7.20797131e-02,
#           3.58620688e-02, -5.83017159e-03, -4.49484888e-02,
#           2.65414884e-02,  2.59321362e-03,  7.58371127e-03,
#          -8.89764275e-03,  4.34977571e-03,  3.40583798e-02],
#         [-7.30198368e-02, -1.36871666e-04, -8.32664185e-03,
#          -4.97052092e-02, -7.35156218e-03,  1.46582627e-03,
#           5.12633042e-03,  1.15450219e-03,  7.15189854e-02,
#           2.65320480e-02, -1.32788131e-02, -4.66041083e-02,
#           1.85199926e-02, -1.42059719e-02,  8.52549937e-03,
#          -9.00300599e-03,  5.97516402e-04,  3.57502609e-02],
#         [-7.10797125e-02,  1.34494387e-02, -1.34719796e-02,
#          -5.63677275e-02, -1.01912614e-02, -1.14956839e-03,
#           1.63063736e-02,  2.93722166e-03,  7.33701446e-02,
#           2.64591281e-02,  2.62408012e-03, -3.48535440e-02,
#           2.38896548e-02, -9.11486163e-03,  8.74652612e-03,
#          -6.92354063e-03, -6.34405036e-03,  2.75024562e-02]]),
#  'theta_estimation': array([ 2.35604885,  0.19336292, -0.44521825,  0.39795742,  0.0339537 ,
#         -0.06496571,  0.02663106,  1.44472395, -2.42902296,  0.17939342,
#          0.74961908, -0.28675625,  0.20703597,  0.08769884, -1.50013121,
#          0.30854321, -0.94306371, -0.31581033]),
#  'computation_time': 19.676629066467285}

# %%
# Truth [15, 10, 7, 0, 3, 9, 12, 13, 6, 1, 17, 4, 5, 11, 16, 2, 14, 8]
sp.order_generation(log[49]["theta_estimation"].tolist())
# Out:
# [0, 7, 10, 3, 15, 12, 1, 9, 13, 4, 6, 5, 11, 17, 2, 16, 14, 8]

# %%
def utility_calculation(scores, rankings, decay_rate = 0.8):
    total_score = 0.0
    for i in range(len(scores)):
        score = scores[i]
        order = rankings[i]
        total_score += sum([score[order[j]] * decay_rate ** j for j in range(len(score))])
    return total_score

def average_utility(scores, rankings, decay_rate = 0.8):
    return utility_calculation(scores, rankings, decay_rate)/len(scores)

# %%
global_ranking = [sp.order_generation(log[49]["theta_estimation"].tolist()) for _ in range(50)]
soc_util = utility_calculation(scores=scores, rankings=global_ranking)
avg_util = soc_util/50.0
print(f"RUMSA Global Ranking List\nSocial Utility: {soc_util}\nAverage Utility: {avg_util}")
# Out:
# RUMSA Global Ranking List
# Social Utility: 21676.885387357124
# Average Utility: 433.53770774714246

# %%
# copied from CAPRA.ipynb which is the global ranking based on CAPRA algorithm from the Twitter-roBERTa-base workspace
CAPRA_ranking = [[0, 1, 15, 10, 7, 5, 3, 9, 12, 6, 17, 4, 13, 11, 2, 16, 8, 14] for _ in range(50)]

# %%
capra_soc_util = utility_calculation(scores=scores, rankings=CAPRA_ranking)
capra_avg_util = capra_soc_util/50.0
print(f"CAPRA Ranking List\nSocial Utility: {capra_soc_util}\nAverage Utility: {capra_avg_util}")
# Out:
# CAPRA Ranking List
# Social Utility: 21344.29940149669
# Average Utility: 426.8859880299338

# %%
# test the utility when ranking list is randomly generated
import random
import numpy as np

random_soc_utils = []
for _ in range(100):
    random_ranking = [random.sample(range(18), 18) for _ in range(50)]
    random_soc_utils.append(utility_calculation(scores=scores, rankings=random_ranking))

temp = np.array(random_soc_utils)
random_soc_util = np.mean(temp)
random_avg_util = random_soc_util/50.0
print(f"Random Ranking List\nSocial Utility: {random_soc_util}\nAverage Utility: {random_avg_util}")
# Out:
# Random Ranking List
# Social Utility: 19643.78409677946
# Average Utility: 392.87568193558917

# %%
# tests of voting rules in compsoc
import compsoc.voter_model as vmodel
import compsoc.evaluate as eval
import compsoc.voting_rules as rules
from compsoc.profile import Profile

# function to transfer profile into compsoc format
def prof_list_to_tuple(profile):
    temp = []
    for p in profile:
        temp.append(tuple(p))
    dic = dict()
    for t in temp:
        if t not in dic.keys():
            dic[t] = 1
        else:
            dic[t] += 1
    result = []
    for k in dic.keys():
        result.append((dic[k], k))
    return result

# and transfer back
def prof_tuple_to_list(profile):
    result = []
    for i in profile:
        for j in range(i[0]):
            result.append(list(i[1]))
    random.shuffle(result)
    return result

test_rules = {
    "Borda": rules.borda.borda_rule,
    "Borda_gamma_0.01": rules.borda_gamma.get_borda_gamma(0.01),
    "Borda_gamma_0.25": rules.borda_gamma.get_borda_gamma(0.25),
    "Borda_gamma_0.5": rules.borda_gamma.get_borda_gamma(0.5),
    "Borda_gamma_0.75": rules.borda_gamma.get_borda_gamma(0.75),
    "Borda_gamma_0.99": rules.borda_gamma.get_borda_gamma(0.99),
    "Borda_gamma_1.00": rules.borda_gamma.get_borda_gamma(1.0),
    "Copeland": rules.copeland.copeland_rule,
    "Dowdall": rules.dowdall.dowdall_rule,
    "Simpson": rules.simpson.simpson_rule,
}

# %%
compsoc_profile = Profile(prof_list_to_tuple(profile_llama3))

# %%
compsoc_rule_utilities = dict()
for rule in test_rules.keys():
    ranking = compsoc_profile.ranking(test_rules[rule])
    # transfer to list format
    ranking = [i for (i, _) in ranking]
    rankings = [ranking for _ in range(50)]
    temp_su = utility_calculation(scores=scores, rankings=rankings)
    temp_au = temp_su/50.0
    compsoc_rule_utilities[rule] = (temp_su, temp_au)
print(compsoc_rule_utilities)
# Out:
# {'Borda': (21676.885387357124, 433.53770774714246), 'Borda_gamma_0.01': (21581.795403869128, 431.63590807738257), 'Borda_gamma_0.25': (21581.795403869128, 431.63590807738257), 'Borda_gamma_0.5': (21648.757336157134, 432.9751467231427), 'Borda_gamma_0.75': (21660.501387357126, 433.21002774714253), 'Borda_gamma_0.99': (21676.885387357124, 433.53770774714246), 'Borda_gamma_1.00': (19884.821031119696, 397.69642062239393), 'Copeland': (21660.501387357126, 433.21002774714253), 'Dowdall': (21660.501387357126, 433.21002774714253), 'Simpson': (20295.456551119692, 405.90913102239386)}

# %%
# generate personalized rankings
zeta_estimation = log[49]['zeta_estimation'].tolist()
theta_estimation = log[49]['theta_estimation'].tolist()

# %%
def personalized_ranking_generation(theta, zeta, zeta_amp=1.0):
    num_voter = len(zeta)
    rankings = []
    np_theta = np.array(theta)
    np_zeta = np.array(zeta)
    for i in range(num_voter):
        personal_utils = np_theta + (np_zeta[i] * zeta_amp)
        personal_utils = personal_utils.tolist()
        rankings.append(sp.order_generation(personal_utils))
    return rankings

# %%
personalized_ranking = personalized_ranking_generation(theta_estimation, zeta_estimation)
per_soc_util = utility_calculation(scores=scores, rankings=personalized_ranking)
per_avg_util = per_soc_util/50.0
print(f"RUMSA Personalized Ranking List\nSocial Utility: {per_soc_util}\nAverage Utility: {per_avg_util}")
# Out:
# RUMSA Personalized Ranking List
# Social Utility: 21701.787435772872
# Average Utility: 434.03574871545743

# %%
#draw the result
import matplotlib.pyplot as plt

average_utilities = [capra_avg_util, random_avg_util]
labels = ["CAPRA", "Random"]

colors = ['#A31D1D','black', '#155E95','#155E95','#155E95','#155E95','#155E95','#155E95','#155E95','#155E95','#155E95','#155E95']

for rule in test_rules.keys():
    average_utilities.append(compsoc_rule_utilities[rule][1])
    labels.append(rule)

fig, ax = plt.subplots()

fig.set_dpi(300)

ax.bar(labels, average_utilities, color=colors)

ax.set_xticklabels(labels, rotation='vertical', ha='center')

ax.set_xlabel('Ranking Methods')

ax.set_ylabel('Average Personal Utilities')

min_y = min(average_utilities)
ax.set_ylim(385, 441)

plt.show()
# Out:
# /var/folders/s8/xfq8jzxs3kq8wp023sbjj8m00000gn/T/ipykernel_24366/376975867.py:19: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels, rotation='vertical', ha='center')

# %%
test_rules = {
    "Borda": rules.borda.borda_rule,
    "Borda_gamma_0.01": rules.borda_gamma.get_borda_gamma(0.01),
    "Borda_gamma_0.25": rules.borda_gamma.get_borda_gamma(0.25),
    "Borda_gamma_0.5": rules.borda_gamma.get_borda_gamma(0.5),
    "Borda_gamma_0.75": rules.borda_gamma.get_borda_gamma(0.75),
    "Borda_gamma_0.99": rules.borda_gamma.get_borda_gamma(0.99),
    "Copeland": rules.copeland.copeland_rule,
    "Dowdall": rules.dowdall.dowdall_rule,
}

average_utilities = [avg_util, per_avg_util]
labels = ["RUMSA Global", "RUMSA Personalized"]

colors = ['#A31D1D','#A31D1D', '#155E95','#155E95','#155E95','#155E95','#155E95','#155E95','#155E95','#155E95','#155E95','#155E95']

for rule in test_rules.keys():
    average_utilities.append(compsoc_rule_utilities[rule][1])
    labels.append(rule)

fig, ax = plt.subplots()

fig.set_dpi(300)

ax.bar(labels, average_utilities, color=colors)

ax.set_xticklabels(labels, rotation='vertical', ha='center')

ax.set_xlabel('Ranking Methods')

ax.set_ylabel('Average Personal Utilities')

min_y = min(average_utilities)
ax.set_ylim(430, 435)

plt.show()
# Out:
# /var/folders/s8/xfq8jzxs3kq8wp023sbjj8m00000gn/T/ipykernel_24366/2910528461.py:27: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels, rotation='vertical', ha='center')
